# %%
# -*- encoding: utf-8 -*-
import os
import sys

# 绘图包
import matplotlib
import matplotlib.pyplot as plt
# 导入相关包
# %matplotlib inline

import numpy as np
import pandas as pd
import csv
import jieba
import re

# %%
# 读取CSV文件
def readDataFile(filename,ptype):
    
    if ptype == 'train':
        # 训练数据4个字段
        COND = 4
    elif ptype == 'test':
        # 测试数据3个字段
        COND = 3

    file = open(filename)
    for line in file:   
        line = line.decode("utf8")
        l_ar = line.split("\t")
        
        if len(l_ar) == COND:
            id = l_ar[0]
            lable = l_ar[3]
            title = scan(l_ar[1])
            content = scan(l_ar[2])
            
            # 标题分词                               
            seg_title = jieba.cut(title)
            seg_title_return = "\t".join(seg_title)
            
            # 正文分词
            seg_content = jieba.cut(content)
            seg_content_return = "\t".join(seg_content)

            if ptype == 'train':     
                # label = line[3]
                yield seg_title_return,seg_content_return,lable
            elif ptype == 'test':
                # doc_id = line[0]
                yield seg_title_return,seg_content_return,id

# %%
# 去除标点符号和特殊符号
def scan(line):
    string = re.sub("[+\s\:\-;?\"\.\!\-\/_,$%^*(+\"\']+|[+——！，“”·-▲▼▽•★ˇ<>「」。？、》《~@#￥%……&*（）]+".decode("utf8"), "".decode("utf8"),line)
    return string

# %%
def makeFile(num):
    
    dataPath = "/home/hadoop/Study/bdci_2017/BDCI2017-360/data/"

    # 训练数据
    train_outfile_title = dataPath + "train/train_output_title" + num + ".tsv"   
    train_outfile_content = dataPath + "train/train_output_content" + num + ".tsv"
    
    # 测试数据
#     test_outfile_title = dataPath + "test/test_output_title" + num + ".tsv"
#     test_outfile_content = dataPath + "test/test_output_content" + num + ".tsv"
    
    # 返回训练数据
    return(train_outfile_title,train_outfile_content)

    # 返回测试数据
#     return(test_outfile_title,test_outfile_content)

# %%
# 把分词以后的结果写入文件
def writeFile(outputfile,newline):
    
    fw = open(outputfile, 'ab')
    fw.write(newline.encode("utf-8"))
    fw.close()

# %%
def run(input_file,ptype):

    # 每次获取最大件数
    STOP_SIZE = 500001
    # 初始化ctr值
    ctr = 0
    
    for i in readDataFile(input_file,ptype):
        if ctr< STOP_SIZE:
            ctr +=1
            print "<%s>" % (ptype) + "第" + str(ctr)+ "件"
            # if ptype == 'train':label = i[2]
            # if ptype == 'test':doc_id = i[2]
            new_title = "__lable__"+i[2].strip()+ "\t"+ i[0]+ "\n"
            new_content = "__lable__"+i[2].strip()+ "\t" + i[1]+ "\n"
            
            #把出力内容，每10W件数据分别存放
            num = ""
            if ctr <= 100000:
                num = "01"
            if ctr > 100000 and ctr <=200000:
                num = "02"
            if ctr > 200000 and ctr <=300000:
                num = "03"
            if ctr > 300000 and ctr <=400000:
                num = "04"
            if ctr > 400000:
                num = "05"
            
            # 训练数据
            train_outfile_title,train_outfile_content = makeFile(num)
            
            # 测试数据
#             test_outfile_title,test_outfile_content = makeFile(num)
            
            #写入新的文件（训练）
            writeFile(train_outfile_title,new_title)
            writeFile(train_outfile_content,new_content)
            
            #写入新的文件（测试）
#             writeFile(test_outfile_title,new_title)
#             writeFile(test_outfile_content,new_content)

# %%
# Main函数
def main():
    
    dataPath = "/home/hadoop/Study/bdci_2017/BDCI2017-360/data/"
    
    # 训练数据
    input_train = dataPath + "train.tsv"
    # 测试数据
    input_test = dataPath + "evaluation_public.tsv"
    
    # 处理训练文件
    run(input_train,'train')
    
    # 处理测试文件
#     run(input_test,'test')

# %%
if __name__ == '__main__':
    main()
# Out:
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第1件
# seg_title: <generator object cut at 0x7f4f6852c550>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第2件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c550>
# <train>第3件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第4件
# seg_title: <generator object cut at 0x7f4f6852c1e0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第5件
# seg_title: <generator object cut at 0x7f4f6852c550>
# seg_content: <generator object cut at 0x7f4f6852c1e0>
# <train>第6件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c550>
# <train>第7件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第8件
# seg_title: <generator object cut at 0x7f4f6852c050>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第9件
# seg_title: <generator object cut at 0x7f4f6852c550>
# seg_content: <generator object cut at 0x7f4f6852c050>
# <train>第10件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c550>
# <train>第11件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第12件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第13件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c3c0>
# <train>第14件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第15件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第16件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c3c0>
# <train>第17件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第18件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第19件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c3c0>
# <train>第20件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第21件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第22件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c3c0>
# <train>第23件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第24件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第25件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c3c0>
# <train>第26件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第27件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第28件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c3c0>
# <train>第29件
# seg_title: <generator object cut at 0x7f4f6852c2d0>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第30件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c2d0>
# <train>第31件
# seg_title: <generator object cut at 0x7f4f6852c370>
# seg_content: <generator object cut at 0x7f4f6852c3c0>
# <train>第32件
# seg_title: <generator object cut at 0x7f4f6852c500>
# seg_content: <generator object cut at 0x7f4f6852c370>
# <train>第33件
# seg_title: <generator object cut at 0x7f4f6852c3c0>
# seg_content: <generator object cut at 0x7f4f6852c500>
# <train>第34件
# seg_title: <generator object cut at 0x7f4f94911280>
# seg_content: <generator object cut at 0x7f4f94911a00>
# <train>第35件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f94911280>
# <train>第36件
# seg_title: <generator object cut at 0x7f4f94911a00>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第37件
# seg_title: <generator object cut at 0x7f4f94911280>
# seg_content: <generator object cut at 0x7f4f68642fa0>
# <train>第38件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f94911280>
# <train>第39件
# seg_title: <generator object cut at 0x7f4f94911a00>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第40件
# seg_title: <generator object cut at 0x7f4f94911280>
# seg_content: <generator object cut at 0x7f4f94911a00>
# <train>第41件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f94911280>
# <train>第42件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第43件
# seg_title: <generator object cut at 0x7f4f685fc140>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第44件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f685fc230>
# <train>第45件
# seg_title: <generator object cut at 0x7f4f685fc730>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第46件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f685fc730>
# <train>第47件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第48件
# seg_title: <generator object cut at 0x7f4f685fc730>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第49件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f685fc730>
# <train>第50件
# seg_title: <generator object cut at 0x7f4f685fc140>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第51件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f685fc140>
# <train>第52件
# seg_title: <generator object cut at 0x7f4f685fc730>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第53件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f685fc730>
# <train>第54件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第55件
# seg_title: <generator object cut at 0x7f4f685fc730>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第56件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f685fc730>
# <train>第57件
# seg_title: <generator object cut at 0x7f4f685fc230>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第58件
# seg_title: <generator object cut at 0x7f4f685fc730>
# seg_content: <generator object cut at 0x7f4f685fc230>
# <train>第59件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f685fc730>
# <train>第60件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第61件
# seg_title: <generator object cut at 0x7f4f685fc730>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第62件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f685fc730>
# <train>第63件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第64件
# seg_title: <generator object cut at 0x7f4f685fc230>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第65件
# seg_title: <generator object cut at 0x7f4f685fc140>
# seg_content: <generator object cut at 0x7f4f685fc230>
# <train>第66件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第67件
# seg_title: <generator object cut at 0x7f4f685fc230>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第68件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f685fc230>
# <train>第69件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第70件
# seg_title: <generator object cut at 0x7f4f685fc230>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第71件
# seg_title: <generator object cut at 0x7f4f685fc140>
# seg_content: <generator object cut at 0x7f4f685fc230>
# <train>第72件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6da6ee10>
# <train>第73件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第74件
# seg_title: <generator object cut at 0x7f4f6da6ee10>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第75件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6da6ee10>
# <train>第76件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f68642a50>
# <train>第77件
# seg_title: <generator object cut at 0x7f4f6da6ee10>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第78件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6da6ee10>
# <train>第79件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第80件
# seg_title: <generator object cut at 0x7f4f68642a50>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第81件
# seg_title: <generator object cut at 0x7f4f6da6ee10>
# seg_content: <generator object cut at 0x7f4f68

# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第410件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第411件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第412件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第413件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第414件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第415件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第416件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第417件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第418件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第419件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第420件
# seg_title: <generator object cut at 0x7f4f6a4547d0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第421件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a4547d0>
# <train>第422件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第423件
# seg_title: <generator object cut at 0x7f4f6a4547d0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第424件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f6a4547d0>
# <train>第425件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第426件
# seg_title: <generator object cut at 0x7f4f6a4547d0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第427件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4547d0>
# <train>第428件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第429件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第430件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第431件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第432件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第433件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第434件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第435件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第436件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第437件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第438件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第439件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第440件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第441件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第442件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第443件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第444件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第445件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第446件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第447件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第448件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第449件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第450件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第451件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第452件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第453件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第454件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第455件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第456件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第457件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第458件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第459件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第460件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第461件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第462件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第463件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第464件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第465件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第466件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第467件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第468件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第469件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第470件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第471件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第472件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第473件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第474件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第475件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第476件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第477件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第478件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第479件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第480件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第481件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第482件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第483件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第484件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第485件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第486件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第487件
# seg_title: <generator object cut at 0x7f4f6a454c30>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第488件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454c30>
# <train>第489件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第490件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第491件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第492件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第493件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第494件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第495件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第496件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第497件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第498件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第499件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第500件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第501件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第502件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第503件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第504件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a4548c0>
# <train>第505件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第506件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第507件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第508件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第509件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第510件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第511件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第512件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第513件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第514件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第515件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第516件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第517件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第518件
# seg_title: <generator object cut at 0x7f4f6a454a50>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# <train>第519件
# seg_title: <generator object cut at 0x7f4f68642eb0>
# seg_content: <generator object cut at 0x7f4f6a454a50>
# <train>第520件
# seg_title: <generator object cut at 0x7f4f686e0eb0>
# seg_content: <generator object cut at 0x7f4f68642eb0>
# <train>第521件
# seg_title: <generator object cut at 0x7f4f6a4548c0>
# seg_content: <generator object cut at 0x7f4f686e0eb0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-2436fc2ab63a> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# <ipython-input-103-b1d40004c55e> in main()
#      10
#      11     # 处理训练文件
# ---> 12     run(input_train,'train')
#      13
#      14     # 处理测试文件
#
# <ipython-input-102-8064935cd7cb> in run(input_file, ptype)
#       6     ctr = 0
#       7
# ----> 8     for i in readDataFile(input_file,ptype):
#       9         if ctr< STOP_SIZE:
#      10             ctr +=1
#
# <ipython-input-98-c25eb44e6e4d> in readDataFile(filename, ptype)
#      28             seg_content = jieba.cut(content)
#      29             print "seg_content:",seg_content
# ---> 30             seg_content_return = "\t".join(seg_content)
#      31
#      32             if ptype == 'train':
#
# /home/hadoop/anaconda2/lib/python2.7/site-packages/jieba/__init__.pyc in cut(self, sentence, cut_all, HMM)
#     299                 continue
#     300             if re_han.match(blk):
# --> 301                 for word in cut_block(blk):
#     302                     yield word
#     303             else:
#
# /home/hadoop/anaconda2/lib/python2.7/site-packages/jieba/__init__.pyc in __cut_DAG(self, sentence)
#     233         DAG = self.get_DAG(sentence)
#     234         route = {}
# --> 235         self.calc(sentence, DAG, route)
#     236         x = 0
#     237         buf = ''
#
# /home/hadoop/anaconda2/lib/python2.7/site-packages/jieba/__init__.pyc in calc(self, sentence, DAG, route)
#     174         for idx in xrange(N - 1, -1, -1):
#     175             route[idx] = max((log(self.FREQ.get(sentence[idx:x + 1]) or 1) -
# --> 176                               logtotal + route[x + 1][0], x) for x in DAG[idx])
#     177
#     178     def get_DAG(self, sentence):
#
# KeyboardInterrupt:
